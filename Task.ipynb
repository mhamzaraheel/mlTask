# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the data set
data = pd.read_csv("Trading-features.csv")

# %%
data
# Out:
#             id  last_price                  created_at        f1     f2    f3  \
# 0     55466910     43138.2  2023-12-27 12:47:41.916971  0.000463  15139 -43.1
# 1     55466909     43138.2  2023-12-27 12:47:40.693372  0.000463  15140 -43.1
# 2     55466908     43138.2  2023-12-27 12:47:39.968797  0.000463  15141 -37.4
# 3     55466907     43138.2  2023-12-27 12:47:38.919784  0.000463  15142 -37.4
# 4     55466906     43132.6  2023-12-27 12:47:37.881533  0.000463  15143 -39.6
# ...        ...         ...                         ...       ...    ...   ...
# 9995  55456903     42753.6  2023-12-27 10:00:09.874616  0.000414  25191 -29.5
# 9996  55456902     42753.6  2023-12-27 10:00:08.803069  0.000414  25192 -29.5
# 9997  55456901     42753.6  2023-12-27 10:00:07.957261  0.000414  25193 -36.7
# 9998  55456900     42753.7  2023-12-27 10:00:06.730827  0.000414  25194 -36.7
# 9999  55456899     42765.6  2023-12-27 10:00:05.707968  0.000414  25196 -36.7
#
#         f4    f5    f6    f7  ...   f152   f153   f154   f155   f156   f157  \
# 0     43.0  -0.1  -4.8  -5.1  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2
# 1     43.0  -0.1  -4.7  -5.1  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2
# 2     43.0   5.6  -1.9  -0.6  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2
# 3     37.4   0.0  -3.7  -6.2  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2
# 4     36.5  -3.1  -3.7  -9.4  ...  689.6 -129.4  689.6 -129.4 -129.4  689.6
# ...    ...   ...   ...   ...  ...    ...    ...    ...    ...    ...    ...
# 9995  29.4  -0.1   3.5   9.6  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2
# 9996  29.4  -0.1   3.4   9.6  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2
# 9997  36.6  -0.1   3.7   9.7  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2
# 9998  48.5  11.8  22.6  21.6  ...  440.3  -41.2  440.3  -41.2  -41.2  440.3
# 9999  48.5  11.8  22.7  19.8  ...  452.2  -29.3  452.2  -29.3  -29.3  452.2
#
#        f158   f159   f160   f161
# 0     695.2 -123.8 -123.8  695.2
# 1     695.2 -123.8 -123.8  695.2
# 2     695.2 -123.8 -123.8  695.2
# 3     695.2 -123.8 -123.8  695.2
# 4     689.6 -129.4 -129.4  689.6
# ...     ...    ...    ...    ...
# 9995  440.2  -41.3  -41.3  440.2
# 9996  440.2  -41.3  -41.3  440.2
# 9997  440.2  -41.3  -41.3  440.2
# 9998  440.3  -41.2  -41.2  440.3
# 9999  452.2  -29.3  -29.3  452.2
#
# [10000 rows x 164 columns]

# %%
# Give all the data information
data.describe(include = 'all')
# Out:
#                   id    last_price                  created_at            f1  \
# count   1.000000e+04  10000.000000                       10000  10000.000000
# unique           NaN           NaN                       10000           NaN
# top              NaN           NaN  2023-12-27 12:47:41.916971           NaN
# freq             NaN           NaN                           1           NaN
# mean    5.546190e+07  42938.580560                         NaN      0.000414
# std     2.890879e+03    205.486455                         NaN      0.000018
# min     5.545690e+07  42659.500000                         NaN      0.000397
# 25%     5.545940e+07  42747.400000                         NaN      0.000400
# 50%     5.546190e+07  42835.850000                         NaN      0.000408
# 75%     5.546441e+07  43145.225000                         NaN      0.000417
# max     5.546691e+07  43262.000000                         NaN      0.000463
#
#                  f2            f3            f4            f5            f6  \
# count   10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# unique          NaN           NaN           NaN           NaN           NaN
# top             NaN           NaN           NaN           NaN           NaN
# freq            NaN           NaN           NaN           NaN           NaN
# mean    20149.80990    -40.236010     42.252370      2.016360      0.523120
# std      2897.95985      7.212493      9.346334      5.339766     12.883223
# min     15139.00000    -57.800000     15.000000    -27.100000    -51.900000
# 25%     17642.00000    -46.000000     35.700000      0.000000     -5.600000
# 50%     20146.00000    -38.200000     40.500000      0.800000      0.000000
# 75%     22652.25000    -34.500000     48.500000      3.900000      5.725000
# max     25196.00000    -22.100000    124.200000     85.300000    135.000000
#
#                   f7  ...          f152          f153          f154  \
# count   10000.000000  ...  10000.000000  10000.000000  10000.000000
# unique           NaN  ...           NaN           NaN           NaN
# top              NaN  ...           NaN           NaN           NaN
# freq             NaN  ...           NaN           NaN           NaN
# mean        1.103560  ...    533.201440    -74.606490    533.201440
# std        17.590602  ...    177.929894     46.736091    177.929894
# min       -59.900000  ...    301.200000   -196.300000    301.200000
# 25%        -8.300000  ...    359.100000   -104.825000    359.100000
# 50%         0.100000  ...    450.800000    -61.200000    450.800000
# 75%         8.800000  ...    712.325000    -37.700000    712.325000
# max       135.700000  ...    831.300000     49.400000    831.300000
#
#                 f155          f156          f157          f158          f159  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean      -74.606490    -74.606490    533.201440    533.201440    -74.606490
# std        46.736091     46.736091    177.929894    177.929894     46.736091
# min      -196.300000   -196.300000    301.200000    301.200000   -196.300000
# 25%      -104.825000   -104.825000    359.100000    359.100000   -104.825000
# 50%       -61.200000    -61.200000    450.800000    450.800000    -61.200000
# 75%       -37.700000    -37.700000    712.325000    712.325000    -37.700000
# max        49.400000     49.400000    831.300000    831.300000     49.400000
#
#                 f160          f161
# count   10000.000000  10000.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean      -74.606490    533.201440
# std        46.736091    177.929894
# min      -196.300000    301.200000
# 25%      -104.825000    359.100000
# 50%       -61.200000    450.800000
# 75%       -37.700000    712.325000
# max        49.400000    831.300000
#
# [11 rows x 164 columns]

# %%
# check the length and shape of the data
print(f"There are {len(data)} rows in the dataset.")
print(f"Shape of Data is {data.shape}",) # >>> (rows , columns)
# Out:
# There are 10000 rows in the dataset.
# Shape of Data is (10000, 164)

# %%
# Convert the date column into date time
data['created_at'] = pd.to_datetime(data['created_at'])
# Extracting the time part
data['created_at'] = data['created_at'].dt.time

# %%
print('Columns with null values and their counts:')
null_columns = data.columns[data.isnull().any()]
for column in null_columns:
    null_count = data[column].isnull().sum()
    null_percentage = (null_count / len(data)) * 100
    print(f'{column}: {null_count} null values ({null_percentage:.2f}%)')
# Out:
# Columns with null values and their counts:
# f24: 21 null values (0.21%)
# f47: 21 null values (0.21%)
# f48: 8 null values (0.08%)
# f49: 8 null values (0.08%)
# f50: 21 null values (0.21%)
# f61: 21 null values (0.21%)
# f62: 8 null values (0.08%)
# f63: 21 null values (0.21%)
# f64: 8 null values (0.08%)
# f65: 21 null values (0.21%)
# f66: 8 null values (0.08%)
# f67: 21 null values (0.21%)
# f68: 8 null values (0.08%)
# f69: 21 null values (0.21%)
# f70: 8 null values (0.08%)
# f71: 21 null values (0.21%)
# f72: 8 null values (0.08%)
# f73: 21 null values (0.21%)
# f74: 8 null values (0.08%)
# f75: 21 null values (0.21%)
# f76: 8 null values (0.08%)
# f101: 8 null values (0.08%)
# f106: 8 null values (0.08%)
# f108: 8 null values (0.08%)
# f110: 8 null values (0.08%)
# f121: 8 null values (0.08%)

# %%
# Remove columns containing null values and ensure that the removal does not significantly reduce the amount of data.
data.dropna(inplace=True)
len(data)
# Out:
# 9979

# %%
# Columns with all values zero , remove all that column
zero_columns = [column for column in data.columns if (data[column] == 0).all()]
print("Columns with all zero values:", zero_columns)
data = data.drop(zero_columns, axis=1)
data.shape
# Out:
# Columns with all zero values: ['f24', 'f47', 'f50', 'f61', 'f63', 'f65', 'f67', 'f69', 'f71', 'f73', 'f75']
# (9979, 153)

# %%
# Drop the row with all zeros values
data = data.loc[(data != 0).any(axis=1)]
data.shape
# Out:
# (9979, 153)

# %%
# Drop the column <<id>>
data.drop("id", axis=1, inplace=True)
data.shape
# Out:
# (9979, 152)

# %%
data
# Out:
#       last_price       created_at        f1     f2    f3    f4    f5    f6  \
# 0        43138.2  12:47:41.916971  0.000463  15139 -43.1  43.0  -0.1  -4.8
# 1        43138.2  12:47:40.693372  0.000463  15140 -43.1  43.0  -0.1  -4.7
# 2        43138.2  12:47:39.968797  0.000463  15141 -37.4  43.0   5.6  -1.9
# 3        43138.2  12:47:38.919784  0.000463  15142 -37.4  37.4   0.0  -3.7
# 4        43132.6  12:47:37.881533  0.000463  15143 -39.6  36.5  -3.1  -3.7
# ...          ...              ...       ...    ...   ...   ...   ...   ...
# 9995     42753.6  10:00:09.874616  0.000414  25191 -29.5  29.4  -0.1   3.5
# 9996     42753.6  10:00:08.803069  0.000414  25192 -29.5  29.4  -0.1   3.4
# 9997     42753.6  10:00:07.957261  0.000414  25193 -36.7  36.6  -0.1   3.7
# 9998     42753.7  10:00:06.730827  0.000414  25194 -36.7  48.5  11.8  22.6
# 9999     42765.6  10:00:05.707968  0.000414  25196 -36.7  48.5  11.8  22.7
#
#         f7    f8  ...   f152   f153   f154   f155   f156   f157   f158   f159  \
# 0     -5.1  -4.3  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 1     -5.1  -2.4  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 2     -0.6  -2.4  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 3     -6.2 -10.2  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2 -123.8
# 4     -9.4 -10.2  ...  689.6 -129.4  689.6 -129.4 -129.4  689.6  689.6 -129.4
# ...    ...   ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9995   9.6   9.7  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 9996   9.6   9.7  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 9997   9.7  12.6  ...  440.2  -41.3  440.2  -41.3  -41.3  440.2  440.2  -41.3
# 9998  21.6  23.7  ...  440.3  -41.2  440.3  -41.2  -41.2  440.3  440.3  -41.2
# 9999  19.8  21.7  ...  452.2  -29.3  452.2  -29.3  -29.3  452.2  452.2  -29.3
#
#        f160   f161
# 0    -123.8  695.2
# 1    -123.8  695.2
# 2    -123.8  695.2
# 3    -123.8  695.2
# 4    -129.4  689.6
# ...     ...    ...
# 9995  -41.3  440.2
# 9996  -41.3  440.2
# 9997  -41.3  440.2
# 9998  -41.2  440.3
# 9999  -29.3  452.2
#
# [9979 rows x 152 columns]

# %%
# Our data set  <<Features>> <<Labels>>
x = data.iloc[:, 1:data.shape[1]]
y = data.iloc[:, 0]
x.shape , y.shape
# Out:
# ((9979, 151), (9979,))

# %%
chosen_feature_index = 1

# %%
# Assuming chosen_feature_index is the index of the feature you want to plot
chosen_feature = x.iloc[:, chosen_feature_index]

# Choose a colormap (e.g., 'viridis', 'plasma', 'magma', 'inferno', etc.)
colormap = 'viridis'

# Scatter plot with colormap
plt.scatter(chosen_feature, y, c=y, cmap=colormap)
plt.xlabel(x.columns[chosen_feature_index])
plt.ylabel('y')
plt.title('Data Before the Normalization')
plt.colorbar(label='Color scale')
plt.show()

# %%
# # Calculate the correlation matrix
# corr_matrix = data.corr()
# corr_matrix
# Out:
#                   id  last_price  created_at        f1        f2        f3  \
# id          1.000000    0.870170    0.999994  0.715610 -0.999994 -0.832428
# last_price  0.870170    1.000000    0.869883  0.543172 -0.869881 -0.747808
# created_at  0.999994    0.869883    1.000000  0.714106 -1.000000 -0.832002
# f1          0.715610    0.543172    0.714106  1.000000 -0.714104 -0.661259
# f2         -0.999994   -0.869881   -1.000000 -0.714104  1.000000  0.832001
# ...              ...         ...         ...       ...       ...       ...
# f157        0.794230    0.983107    0.793676  0.546212 -0.793673 -0.701679
# f158        0.794230    0.983107    0.793676  0.546212 -0.793673 -0.701679
# f159       -0.460389   -0.300865   -0.458767 -0.813458  0.458766  0.491244
# f160       -0.460389   -0.300865   -0.458767 -0.813458  0.458766  0.491244
# f161        0.794230    0.983107    0.793676  0.546212 -0.793673 -0.701679
#
#                   f4        f5        f6        f7  ...      f152      f153  \
# id          0.661117  0.032799  0.004215  0.005995  ...  0.794230 -0.460389
# last_price  0.628199  0.089479  0.034578  0.047083  ...  0.983107 -0.300865
# created_at  0.660872  0.032946  0.004374  0.006229  ...  0.793676 -0.458767
# f1          0.476699 -0.058793 -0.038621 -0.057812  ...  0.546212 -0.813458
# f2         -0.660871 -0.032946 -0.004372 -0.006228  ... -0.793673  0.458766
# ...              ...       ...       ...       ...  ...       ...       ...
# f157        0.591165  0.086965  0.032412  0.042938  ...  1.000000 -0.329335
# f158        0.591165  0.086965  0.032412  0.042938  ...  1.000000 -0.329335
# f159       -0.280646  0.172307  0.180359  0.236978  ... -0.329335  1.000000
# f160       -0.280646  0.172307  0.180359  0.236978  ... -0.329335  1.000000
# f161        0.591165  0.086965  0.032412  0.042938  ...  1.000000 -0.329335
#
#                 f154      f155      f156      f157      f158      f159  \
# id          0.794230 -0.460389 -0.460389  0.794230  0.794230 -0.460389
# last_price  0.983107 -0.300865 -0.300865  0.983107  0.983107 -0.300865
# created_at  0.793676 -0.458767 -0.458767  0.793676  0.793676 -0.458767
# f1          0.546212 -0.813458 -0.813458  0.546212  0.546212 -0.813458
# f2         -0.793673  0.458766  0.458766 -0.793673 -0.793673  0.458766
# ...              ...       ...       ...       ...       ...       ...
# f157        1.000000 -0.329335 -0.329335  1.000000  1.000000 -0.329335
# f158        1.000000 -0.329335 -0.329335  1.000000  1.000000 -0.329335
# f159       -0.329335  1.000000  1.000000 -0.329335 -0.329335  1.000000
# f160       -0.329335  1.000000  1.000000 -0.329335 -0.329335  1.000000
# f161        1.000000 -0.329335 -0.329335  1.000000  1.000000 -0.329335
#
#                 f160      f161
# id         -0.460389  0.794230
# last_price -0.300865  0.983107
# created_at -0.458767  0.793676
# f1         -0.813458  0.546212
# f2          0.458766 -0.793673
# ...              ...       ...
# f157       -0.329335  1.000000
# f158       -0.329335  1.000000
# f159        1.000000 -0.329335
# f160        1.000000 -0.329335
# f161       -0.329335  1.000000
#
# [164 rows x 164 columns]

# %%
# # Calculate the correlation matrix
# corr_matrix = data.corr()
#
# # Plot the heatmap
# sns.heatmap(corr_matrix, cmap="coolwarm", annot=False)
# plt.show()

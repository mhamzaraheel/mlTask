# %%
import  cv2 as cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r'car.webp')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
top_left = (15, 220)
bottom_right = (260, 430)
color = (0, 255, 0)
thickness = 2

# %%
# Draw the rectangle on the image
x = cv2.rectangle(image, top_left, bottom_right, color, thickness)

# %%
top_left = (275, 220)
bottom_right = (520, 430)
color = (0, 255, 0)
thickness = 2

# %%
# Draw the rectangle on the image
x = cv2.rectangle(image, top_left, bottom_right, color, thickness)

# %%
top_left = (535, 220)
bottom_right = (780, 430)
color = (0, 255, 0)
thickness = 2

# %%
# Draw the rectangle on the image
x = cv2.rectangle(image, top_left, bottom_right, color, thickness)

# %%
plt.imshow(image)
